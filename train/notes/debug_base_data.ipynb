# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_path = "../base_data/infos.npz"
data_all = np.load(data_path)

data_actions = data_all["actions"]
data_positions = data_all["positions"]
data_angles = data_all["angles"]
data_rewards = data_all["rewards"]
data_dones = data_all["dones"]

# %%
print(data_actions.shape)
print(data_positions.shape)
print(data_angles.shape)
print(data_dones.shape)
# Out:
# (100, 2)
# (100, 3)
# (100,)
# (100,)

# %%
for i, done in enumerate(data_dones):
    print("i={}, done={}".format(i, done))
# Out:
# i=0, done=False
# i=1, done=False
# i=2, done=False
# i=3, done=False
# i=4, done=False
# i=5, done=False
# i=6, done=False
# i=7, done=False
# i=8, done=False
# i=9, done=False
# i=10, done=False
# i=11, done=False
# i=12, done=False
# i=13, done=False
# i=14, done=False
# i=15, done=False
# i=16, done=False
# i=17, done=False
# i=18, done=False
# i=19, done=False
# i=20, done=False
# i=21, done=False
# i=22, done=False
# i=23, done=False
# i=24, done=False
# i=25, done=False
# i=26, done=False
# i=27, done=False
# i=28, done=False
# i=29, done=False
# i=30, done=False
# i=31, done=True
# i=32, done=False
# i=33, done=False
# i=34, done=False
# i=35, done=False
# i=36, done=False
# i=37, done=False
# i=38, done=False
# i=39, done=False
# i=40, done=False
# i=41, done=False
# i=42, done=False
# i=43, done=False
# i=44, done=False
# i=45, done=False
# i=46, done=False
# i=47, done=False
# i=48, done=False
# i=49, done=False
# i=50, done=False
# i=51, done=False
# i=52, done=False
# ...

# %%
for i, position in enumerate(data_positions):
    print("i={}, position={}".format(i, position))
# Out:
# i=0, position=[13.2177372   0.49176988  0.56340694]
# i=1, position=[13.2177372   0.49001417  0.56340694]
# i=2, position=[13.2177372   0.49000013  0.56340694]
# i=3, position=[13.2177372   0.49000004  0.56340694]
# i=4, position=[13.2177372   0.49000004  0.56340694]
# i=5, position=[13.2177372   0.49000004  0.56340694]
# i=6, position=[13.31526375  0.49000004  0.58016247]
# i=7, position=[13.54624176  0.49000004  0.6172393 ]
# i=8, position=[13.89640045  0.49000004  0.66331947]
# i=9, position=[14.35115433  0.49000004  0.72450757]
# i=10, position=[14.89959908  0.49000004  0.78694785]
# i=11, position=[15.53129101  0.49000004  0.83903092]
# i=12, position=[16.23617363  0.49000004  0.89459282]
# i=13, position=[17.00466537  0.49000004  0.96505076]
# i=14, position=[17.83027458  0.49000004  1.04156935]
# i=15, position=[18.70559692  0.49000004  1.13035643]
# i=16, position=[19.62608147  0.49000004  1.21768129]
# i=17, position=[20.58691788  0.49000004  1.29195774]
# ...

# %%
for i, angle in enumerate(data_angles):
    print("i={}, angle={}".format(i, angle))
# Out:
# i=0, angle=1.295932935426418
# i=1, angle=1.295932935426418
# i=2, angle=1.295932935426418
# i=3, angle=1.295932935426418
# i=4, angle=1.295932935426418
# i=5, angle=1.4006528237041322
# i=6, angle=1.4006528237041322
# i=7, angle=1.505372845139901
# i=8, angle=1.4006529568621866
# i=9, angle=1.5053729782979555
# i=10, angle=1.61009286657567
# i=11, angle=1.505372845139901
# i=12, angle=1.4006529568621866
# i=13, angle=1.5053729782979555
# i=14, angle=1.4006530900202412
# i=15, angle=1.50537311145601
# i=16, angle=1.61009286657567
# i=17, angle=1.5053729782979555
# i=18, angle=1.4006530900202412
# i=19, angle=1.50537311145601
# i=20, angle=1.61009286657567
# i=21, angle=1.5053729782979555
# i=22, angle=1.61009286657567
# i=23, angle=1.505372845139901
# i=24, angle=1.4006529568621866
# i=25, angle=1.5053729782979555
# i=26, angle=1.4006530900202412
# i=27, angle=1.295933201742527
# i=28, angle=1.4006532231782958
# i=29, angle=1.295933201742527
# i=30, angle=1.1912133134648126
# ...
